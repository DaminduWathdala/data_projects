# %%
# !pip install numpy pandas matplotlib seaborn
# Out:
# ...
#   Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.5.1-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
# Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.5 MB 3.2 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.5 MB 3.2 MB/s eta 0:00:03
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../data_sets/Superstore.csv",encoding='latin-1')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data = data.drop(columns=['Row ID','Order ID'])

# %%
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode Customer ID    Customer Name  \
# 0   11/8/2016  11/11/2016    Second Class    CG-12520      Claire Gute
# 1   11/8/2016  11/11/2016    Second Class    CG-12520      Claire Gute
# 2   6/12/2016   6/16/2016    Second Class    DV-13045  Darrin Van Huff
# 3  10/11/2015  10/18/2015  Standard Class    SO-20335   Sean O'Donnell
# 4  10/11/2015  10/18/2015  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky        42420  South
# 1   Consumer  United States        Henderson    Kentucky        42420  South
# 2  Corporate  United States      Los Angeles  California        90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   str
#  1   Ship Date      9994 non-null   str
#  2   Ship Mode      9994 non-null   str
#  3   Customer ID    9994 non-null   str
#  4   Customer Name  9994 non-null   str
#  5   Segment        9994 non-null   str
#  6   Country        9994 non-null   str
#  7   City           9994 non-null   str
#  8   State          9994 non-null   str
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   str
#  11  Product ID     9994 non-null   str
#  12  Category       9994 non-null   str
#  13  Sub-Category   9994 non-null   str
#  14  Product Name   9994 non-null   str
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
#  17  Discount       9994 non-null   float64
# ...

# %%
data['Year'] = data['Order Date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data['Year'] = data['Order Date'].dt.year
#
# File ~\Desktop\data_vis\myenv\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# File ~\Desktop\data_vis\myenv\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# ...

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data['Order Year'] = data['Order Date'].dt.year
data.head()
# Out:
#   Order Date   Ship Date       Ship Mode Customer ID    Customer Name  \
# 0 2016-11-08  11/11/2016    Second Class    CG-12520      Claire Gute
# 1 2016-11-08  11/11/2016    Second Class    CG-12520      Claire Gute
# 2 2016-06-12   6/16/2016    Second Class    DV-13045  Darrin Van Huff
# 3 2015-10-11  10/18/2015  Standard Class    SO-20335   Sean O'Donnell
# 4 2015-10-11  10/18/2015  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City       State  Postal Code  ...  \
# 0   Consumer  United States        Henderson    Kentucky        42420  ...
# 1   Consumer  United States        Henderson    Kentucky        42420  ...
# 2  Corporate  United States      Los Angeles  California        90036  ...
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  ...
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data = data.drop('Ship Date',axis=1)

# %%
data.head()
# Out:
#         Ship Mode Customer ID    Customer Name    Segment        Country  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
#
#               City       State  Postal Code Region       Product ID  \
# 0        Henderson    Kentucky        42420  South  FUR-BO-10001798
# 1        Henderson    Kentucky        42420  South  FUR-CH-10000454
# 2      Los Angeles  California        90036   West  OFF-LA-10000240
# 3  Fort Lauderdale     Florida        33311  South  FUR-TA-10000577
# 4  Fort Lauderdale     Florida        33311  South  OFF-ST-10000760
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# ...

# %%
data = data.drop(columns=['Customer ID','Customer Name','Product ID','Year'])

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category  \
# 0        42420  South        Furniture    Bookcases
# 1        42420  South        Furniture       Chairs
# 2        90036   West  Office Supplies       Labels
# 3        33311  South        Furniture       Tables
# 4        33311  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# ...

# %%
data['Segment'].describe()
# Out:
# count         9994
# unique           3
# top       Consumer
# freq          5191
# Name: Segment, dtype: object

# %%
plt.pie(data['Segment'].value_counts(),labels=data['Segment'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
data['Country'].describe()
# Out:
# count              9994
# unique                1
# top       United States
# freq               9994
# Name: Country, dtype: object

# %%
data = data.drop('Country',axis=1)

# %%
data['City'].describe()
# Out:
# count              9994
# unique              531
# top       New York City
# freq                915
# Name: City, dtype: object

# %%
top_cities = data['City'].value_counts().head(10)
top_cities
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Name: count, dtype: int64

# %%
plt.pie(top_cities,labels=top_cities.index,autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=top_cities.values,y=top_cities.index)
plt.ylabel('City')
plt.xlabel('Count')
plt.grid()
plt.show()

# %%
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# ...

# %%
data['State'].describe()
# Out:
# count           9994
# unique            49
# top       California
# freq            2001
# Name: State, dtype: object

# %%
top_State = data['State'].value_counts().head(10)
top_State
# Out:
# State
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: count, dtype: int64

# %%
plt.pie(top_State.values,labels=top_State.index,autopct='%1.1f%%')
plt.show()

# %%
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# ...

# %%
data.drop('Postal Code',axis=1)
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category  \
# 0           Furniture    Bookcases
# 1           Furniture       Chairs
# 2     Office Supplies       Labels
# ...

# %%
top_sub_categ = data['Sub-Category'].value_counts().head(10)
top_sub_categ
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Name: count, dtype: int64

# %%
low_sub_categ = data['Sub-Category'].value_counts().tail(10)
low_sub_categ
# Out:
# Sub-Category
# Chairs        617
# Appliances    466
# Labels        364
# Tables        319
# Envelopes     254
# Bookcases     228
# Fasteners     217
# Supplies      190
# Machines      115
# Copiers        68
# Name: count, dtype: int64

# %%
plt.pie(top_sub_categ.values,labels=top_sub_categ.index,autopct='%1.1f%%')
plt.show()

# %%
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# ...

# %%
top_product_name = data['Product Name'].value_counts().head(10)
top_product_name
# Out:
# Product Name
# Staple envelope                                              48
# Easy-staple paper                                            46
# Staples                                                      46
# Avery Non-Stick Binders                                      20
# Staples in misc. colors                                      19
# Staple remover                                               18
# KI Adjustable-Height Table                                   18
# Storex Dura Pro Binders                                      17
# Staple-based wall hangings                                   16
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling    15
# Name: count, dtype: int64

# %%
low_product_name = data['Product Name'].value_counts().tail(10)
low_product_name
# Out:
# Product Name
# 4009 Highlighters                                               1
# Global Enterprise Series Seating Low-Back Swivel/Tilt Chairs    1
# Grip Seal Envelopes                                             1
# Penpower WorldCard Pro Card Scanner                             1
# Sony 8GB Class 10 Micro SDHC R40 Memory Card                    1
# RCA ViSYS 25425RE1 Corded phone                                 1
# Cisco 8961 IP Phone Charcoal                                    1
# Eureka Hand Vacuum, Bagless                                     1
# LG G2                                                           1
# Eldon Jumbo ProFile Portable File Boxes Graphite/Black          1
# Name: count, dtype: int64

# %%
plt.pie(low_product_name .values,labels=low_product_name .index,autopct='%0.1f%%')
plt.show()

# %%
category_profit = data.groupby('Category')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
category_profit
# Out:
#           Category       Profit
# 2       Technology  145454.9481
# 1  Office Supplies  122490.8008
# 0        Furniture   18451.2728

# %%
sns.barplot(x=category_profit['Category'],y=category_profit['Profit'])
ptl.xlabel("Category")
plt.ylabel("Profit")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 sns.barplot(x=category_profit['Category'],y=category_profit['Profit'])
# ----> 2 ptl.xlabel("Category")
#       3 plt.ylabel("Profit")
#       4 plt.grid()
#       5 plt.show()
#
# NameError: name 'ptl' is not defined

# %%
index1 = []
index1.append(data[data['Profit']<0].index)

# %%
index1
# Out:
# [Index([   3,   14,   15,   23,   27,   28,   32,   36,   38,   39,
#         ...
#         9878, 9899, 9903, 9912, 9919, 9920, 9921, 9931, 9937, 9962],
#        dtype='int64', length=1871)]

# %%
selected_categories = data['Sub-Category'].iloc[index1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 selected_categories = data['Sub-Category'].iloc[index1]
#
# File ~\Desktop\data_vis\myenv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\data_vis\myenv\Lib\site-packages\pandas\core\indexing.py:1764, in _iLocIndexer._getitem_axis(self, key, axis)
#    1762 # a list of integers
#    1763 elif is_list_like_indexer(key):
# -> 1764     return self._get_list_axis(key, axis=axis)
#    1766 # a single integer
#    1767 else:
#    1768     key = item_from_zerodim(key)
#
# ...

# %%
index1 = np.array(index1)
index= index1.flatten().tolist()

# %%
selected_categories = data['Sub-Category'].iloc[index]

# %%
selected_categories
# Out:
# 3           Tables
# 14      Appliances
# 15         Binders
# 23          Chairs
# 27       Bookcases
#            ...
# 9920       Binders
# 9921       Binders
# 9931     Bookcases
# 9937        Tables
# 9962     Bookcases
# Name: Sub-Category, Length: 1871, dtype: str

# %%
selected_categories.values
# Out:
# <StringArray>
# [     'Tables',  'Appliances',     'Binders',      'Chairs',   'Bookcases',
#      'Binders',     'Binders', 'Furnishings',   'Bookcases',      'Chairs',
#  ...
#       'Phones',      'Tables', 'Furnishings',      'Chairs',      'Chairs',
#      'Binders',     'Binders',   'Bookcases',      'Tables',   'Bookcases']
# Length: 1871, dtype: str

# %%
selected_categories_profit = data['Profit'].iloc[index]

# %%
data2 = pd.DataFrame({
    'category': selected_categories,
    'Profit': selected_categories_profit
})

# %%
data2
# Out:
#         category     Profit
# 3         Tables  -383.0310
# 14    Appliances  -123.8580
# 15       Binders    -3.8160
# 23        Chairs    -1.0196
# 27     Bookcases -1665.0522
# ...          ...        ...
# 9920     Binders   -35.8176
# 9921     Binders    -4.5936
# 9931   Bookcases   -40.1960
# 9937      Tables    -1.7772
# 9962   Bookcases   -67.6704
#
# [1871 rows x 2 columns]

# %%
category_profit_minus= data2.groupby('category')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
category_profit_minus
# Out:
#        category      Profit
# 5     Fasteners    -33.1952
# 0   Accessories   -930.6265
# 10     Supplies  -3015.6219
# 9       Storage  -6426.3038
# 6   Furnishings  -6490.9134
# 8        Phones  -7530.6235
# 1    Appliances  -8629.6412
# 4        Chairs  -9880.8413
# 3     Bookcases -12152.2060
# 7      Machines -30118.6682
# 11       Tables -32412.1483
# 2       Binders -38510.4964

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=category_profit_minus['category'],y=category_profit_minus['Profit'])
plt.grid()
plt.xlabel('Category')
plt.ylabel('-Profit')
plt.show()
